# %%
import pandas as pd
import numpy as np

# %%
from pandas_profiling import ProfileReport

# %%
cash_flow = pd.read_csv("./Jobs_dataset/naukri_data_science_jobs_india.csv")

# %%
# ticker_to_company = pd.read_csv("./Chinese_Company_dataset/map_ticker_to_company.csv")

# %%
# ticker_to_company.head()
# Out:
#      ticker company_name
# 0  sh600000         浦发银行
# 1  sh600004         白云机场
# 2  sh600006         东风汽车
# 3  sh600007         中国国贸
# 4  sh600008         首创环保

# %%
# Generate Report
profile = ProfileReport(cash_flow, title="Data Science Jobs Report", minimal=False)

# %%
profile.to_file("./Jobs_dataset/jobs_report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
